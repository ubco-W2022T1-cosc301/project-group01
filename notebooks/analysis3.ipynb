# %% [markdown]
# # Peter O. Idoko

# %% [markdown]
# ## Research question/interests
#
# I am interested in researching the relationship between race/ethnicity, test preparation, and standardized test scores. I find these topics interesting because as a black international student who relied mainly on the SAT to get into University, I think it would be interesting to see if my race and the availability of test prep influenced my scores. Going further, I think it would also be beneficial in an educational context to analyze the disparity in scores according to race and to also identify if test prep is more prevalent in certain races and how they affect standardized test scores.

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('../data/raw/exams.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# This is a table of all the values in the dataset that was loaded. The variables I will be using for my research are the 'race/ethnicity', 'test preparation course', and the three test score variables as they pertain to my research question.
# 1. race/ethnicity
#     - This variable has 5 different groups represented as 'A' through 'E' to represent different racial/ethnical groups who are represented in the dataset.
# 1. test preparation course
#     - This variable describes whether a  student has completed a test preparation course or not
# 1. math score, reading score, and writing score
#     - These variables represent the score each student recieved after taking the test.

# %% [markdown]
# # Tasks 1 and 2
# These two tasks were combined because they intertwined with each other and as such it was more efficient to complete them together.

# %%
data['total score']=data['writing score']+data['reading score']+data['math score']
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# I summed all of the score values to a total score for overall comparison purposes. This helps when looking at overall scores in relation to my research scores.

# %%
# Task 1-3 Milestone 3

import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
data = data.drop(columns = ['gender','lunch','parental level of education'])

data['race/ethnicity']=data['race/ethnicity'].replace(['group A','group B','group C','group D','group E'],[1,2,3,4,5])
data
# Out:
#      race/ethnicity test preparation course  math score  reading score  \
# 0                 1               completed          67             67
# 1                 4                    none          40             59
# 2                 5                    none          59             60
# 3                 2                    none          77             78
# 4                 5               completed          78             73
# ..              ...                     ...         ...            ...
# 995               3                    none          73             70
# 996               4               completed          85             91
# 997               3                    none          32             35
# 998               3                    none          73             74
# 999               1               completed          65             60
#
#      writing score  total score
# 0               63          197
# 1               55          154
# ...

# %% [markdown]
# I dropped the "gender", "parental level of education", and "lunch" columns because they did not pertain to the topic of my research.

# %%
sns.pairplot(data,
             hue='test preparation course', 
             corner = True,
             vars = ["math score", "reading score", "writing score", "total score"])

# %% [markdown]
# ## Fig 1.
# This visual representation shows the relation between the different reading scores and whether or not a test preparation course was done. From this graph you can see the people who have completed test prep. courses tend to do better overall than people who did not. Similarly, there is a positive corelation between each pair of scores.

# %%
sns.barplot(x='race/ethnicity',y='total score', data =data)
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='total score'>

# %% [markdown]
# ## Fig. 2
# This graph shows the correlation between the different race/ethnicity groups and overall score. The graph shows that there is certain racial/ethnical groups tend to do better than others. Although there is not a significant difference, it is still worth noting.

# %%
sns.displot(data,x="race/ethnicity",y="total score",hue = 'test preparation course',binwidth=(.5,2))

# %% [markdown]
# ## Fig. 3
# This graph shows the relation between different racial groups, the presence/lack of test prep courses. This graph shows how students from groups 4, 5, and 1 have larger amount of people who completed test prep courses and as such they were most prevalent in the higher scores. This supports the claim that there is disparity in the completion of test prep courses among racial/ethnical groups which results in better performance for said groups.

# %%
data.describe()
# Out:
#        race/ethnicity   math score  reading score  writing score  total score
# count     1000.000000  1000.000000    1000.000000    1000.000000  1000.000000
# mean         3.161000    66.396000      69.002000      67.738000   203.136000
# std          1.132414    15.402871      14.737272      15.600985    43.542732
# min          1.000000    13.000000      27.000000      23.000000    65.000000
# 25%          2.000000    56.000000      60.000000      58.000000   175.750000
# 50%          3.000000    66.500000      70.000000      68.000000   202.000000
# 75%          4.000000    77.000000      79.000000      79.000000   235.000000
# max          5.000000   100.000000     100.000000     100.000000   300.000000

# %% [markdown]
# This function call produces a break down of the scores in the data set.

# %%
data.dropna()
# Out:
#      race/ethnicity test preparation course  math score  reading score  \
# 0                 1               completed          67             67
# 1                 4                    none          40             59
# 2                 5                    none          59             60
# 3                 2                    none          77             78
# 4                 5               completed          78             73
# ..              ...                     ...         ...            ...
# 995               3                    none          73             70
# 996               4               completed          85             91
# 997               3                    none          32             35
# 998               3                    none          73             74
# 999               1               completed          65             60
#
#      writing score  total score
# 0               63          197
# 1               55          154
# ...

# %% [markdown]
# The method call above intends to remove rows with null values. However, the data set being used is sufficiently filled out hence there were no rows containing null values.

# %% [markdown]
# # Data Analysis Pipeline
# 1. Load Data
#     * Uploaded files
#     * Checked for/deleted rows with null values
# 2. Clean Data
#     * removed gender, parental level of education, and lunch columns as they do not pertain to my research.
#     * The data in the data set was very comprehensive so there were little to no redundant values.
# 3. Process Data
#     * Created a new column for the total standardized testing score for overall comparison.
#     * I changed the naming of the groups in the race/ethnicity column to numbers to represent the groups. This made it easier for me to make comparisons for race/ethnicity along side whether or not test preparation was completed and total score.
# 4. Wrangle Data
#     * The data set was sufficient to the research so there was no wrangling needed.

# %% [markdown]
# # Task 3

# %%
d = pd.read_csv('../data/raw/exams.csv')
d = (d
     .drop(columns = ['gender','lunch','parental level of education'])
     .dropna()
     .assign(total=d.iloc[:,[5,6,7]].sum(axis=1))
     .replace(['group A','group B','group C', 'group D', 'group E'],[1,2,3,4,5])
    )
d
# Out:
#      race/ethnicity test preparation course  math score  reading score  \
# 0                 1               completed          67             67
# 1                 4                    none          40             59
# 2                 5                    none          59             60
# 3                 2                    none          77             78
# 4                 5               completed          78             73
# ..              ...                     ...         ...            ...
# 995               3                    none          73             70
# 996               4               completed          85             91
# 997               3                    none          32             35
# 998               3                    none          73             74
# 999               1               completed          65             60
#
#      writing score  total
# 0               63    197
# 1               55    154
# 2               50    169
# ...

# %% [markdown]
# Here, I reapplied all the functions used in tasks 1 and 2 on a copy of the same dataset. The difference, however, is I used method chaining to complete the task which made the code much easier to read and reduced the amount of code required.

# %%
from project_functions3 import load_and_process   
d = load_and_process('../data/raw/exams.csv')
d
# Out:
#      race/ethnicity test preparation course  math score  reading score  \
# 0                 1               completed          67             67
# 1                 4                    none          40             59
# 2                 5                    none          59             60
# 3                 2                    none          77             78
# 4                 5               completed          78             73
# ..              ...                     ...         ...            ...
# 995               3                    none          73             70
# 996               4               completed          85             91
# 997               3                    none          32             35
# 998               3                    none          73             74
# 999               1               completed          65             60
#
#      writing score  total
# 0               63    197
# 1               55    154
# 2               50    169
# ...

# %% [markdown]
# Similarly, The cell above uses method chaining as well. However, in this example, the method is in another page and I imported and used the method to perform the needed operations.

# %% [markdown]
# # Conclusion
# After conducting my EDA and looking at the dataset through the lens of the research question proposed at the beginning, I have found that racial/ethnical groups correlate with whether or not test preparation courses are completed and ultimately standardized test scores. From the data visualizations I have present, I believe that looking at the correlation between the total score in comparison to the racial/ethnical groups and the presence/lack of test preparation is a reasonable basis for my data analysis. These data representations showed that certain racial/ethnical groups had more people who had completed test prep courses and as such performed better in the standardized tests. As such, I am able to infer that there is a bias in standardized testing as a result of racial/ethnical background. This can be seen in Fig. 2 where it illustrates how some racial/ethnical groups had a larger number of people who completed test prep courses and as a result had a larger number of people who performed above average. Whether it is because of availability or personal choice, there is an inbalance in the number of people who completed test prep courses as opposed to those who didn't per racial/ethincal group and this affects overall test scores.
#
# These results are interesting to me because I had to rely on standardized testing to get into University and I find it interesting to see how according to trends, I may have potentially done better or worse had I belonged to a different racial group. Furthermore, for me test prep courses were either not available or very scarce. Putting this in context of the research, I find it interesting to see that some groups had more people who had completed test prep courses and how that put them in a better place to perform at a higher level.
#
# Exploring these results have been very interesting to me because they pertain to me personally and I believe they illustrate how far from standard standardized tests are.

# %%
d.to_csv('../data/processed/analysis3.csv', index = False)
